# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# As of now, there are TWO main questions Elite F1 would like to know:
# 1. What player performance associates stronly with the easiness of the Final Round groups on Sundays?
# 2. What player performance associates with falling with other fellow players in the same groups? Essentially, Elite F1 wants to understand how players are assigned to groups.

# %% [markdown]
# I have ideas about answering the first question. We can simply use linear regression (see: https://machinelearningmastery.com/linear-regression-for-machine-learning/) to see if a pattern emerges.

# %% [markdown]
# #### Importing libraries. Making my life easier!

# %%
import numpy as np
import math
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from itertools import product
from tqdm.notebook import tqdm, trange

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %% [markdown]
# #### Reading the data

# %%
raw_data = pd.read_csv("../../data/GP_220123.csv")
raw_data
# Out:
#    Medal  Div             Loc Player TIER  Sunday Group  \
# 0      1  NaN           Natal           B           NaN
# 1      1  NaN       off whats           A           NaN
# 2      1  NaN         Goiania           B           NaN
# 3      1  NaN             NaN           E           NaN
# 4      2  NaN              41           B           NaN
# 5      2  s/c             NaN           E           NaN
# 6      3  NaN             NaN           C           NaN
# 7      3  NaN              11           A           NaN
# 8     10  NaN           Caico           A           NaN
# 9      1  NaN       Cariacica           A           NaN
# 10     2  NaN        Brasilia           A           NaN
# 11     2  NaN              11           A           NaN
# 12     3    2     x Joseilton           D           NaN
# 13     2  NaN  Cps-Lim-MGuacu           A           NaN
# 14     3  NaN    Porto Alegre           D           NaN
# 15    10  NaN              11           B           NaN
# 16    10  NaN              11           B           NaN
# 17    10  NaN      Votorantim           C           NaN
# 18    10  NaN              11           C           NaN
# 19     F    2         x Diego           D           NaN
# 20    10  NaN              11           B           NaN
# 21     3  NaN        Sao Sepe           B           NaN
# 22     2  NaN              21           A           NaN
# 23     2  NaN         x Alain           D           NaN
# 24     3  NaN              21           B           NaN
# 25    10  NaN       Penapolis           B           NaN
# 26    10  NaN        Jaboatao           B           NaN
# 27     1  NaN         Jundiai           B           NaN
# 28    10  NaN       Fortaleza           C           NaN
# 29    10  NaN              21           B           NaN
# 30    10  NaN      JP/Campina           A           NaN
# 31     F  s/c            CAN?           E           NaN
# 32    10  NaN      S.Cruz Sul           B           NaN
# 33    10  NaN              11           B           NaN
# 34    10  NaN             UCR           E           NaN
# 35    10  NaN              21           B           NaN
# 36    10  NaN             CAN           E           NaN
# 37     F  NaN              47           C           NaN
# 38    10  NaN     Lima Duarte           B           NaN
# 39     F  NaN       Penapolis           C           NaN
# 40     F  NaN              US           E           NaN
# 41    10  NaN       Fortaleza           C           NaN
# 42     F  NaN       Sao Borja           C           NaN
# 43     F  NaN    SJ Rio Claro           C           NaN
# 44    10  NaN              21           C           NaN
# 45     F  NaN              11           C           NaN
# 46     F  NaN              47           C           NaN
# 47     F  NaN              31           C           NaN
# 48     F  NaN              31           C           NaN
# 49     F  NaN   SJ Patrocinio           B           NaN
# 50     F  NaN        Juazeiro           D           NaN
# 51   NaN  off              43         NaN           NaN
# 52   NaN    2             NaN         NaN           NaN
# 53    10    2              81         NaN           NaN
# 54     F  NaN       off whats           D           NaN
# 55   NaN  off              41         NaN           NaN
# 56   NaN  NaN             NaN         NaN           NaN
# 57   NaN  NaN             NaN         NaN           NaN
# 58   NaN  NaN             NaN         NaN           NaN
#
#                    Player  SUNDAY pts  SUNDAY pos. SUN DAY group  \
# 0         Adriano Martins       470.0          1.0         SA 77
# 1   Copersucar Fittipaldi       470.0          1.0         SA 39
# 2           Jose Fernando       470.0          1.0         SA 25
# 3             Krystian RS       470.0          1.0         alone
# 4           Edson Marcelo       470.0          2.0         SA 81
# 5             Guest850894       470.0          2.0         alone
# 6         David Hollygans       470.0          3.0         alone
# 7          Felipe Cimadon       470.0          3.0         SA 85
# 8        Joseilton Araujo       470.0          4.0         SA 39
# 9          Renato Ribeiro       469.0          1.0         SA 73
# 10           Alan Parrini       469.0          2.0         SA 77
# 11        Jeremias Preuss       469.0          2.0         SA 82
# 12             Dom Alonso       465.0          3.0         SA 25
# 13           Julio Campos       469.0          2.0         SA 55
# 14             Lucas Kern       469.0          3.0         SA 82
# 15          Eliesley Reis       469.0          6.0         SA 85
# 16      Guilherme Gontier       469.0          5.0         SA 85
# 17        Marcellus Lopes       469.0          4.0         SA 77
# 18          Sidney Junior       469.0          6.0         SA 85
# 19          Gil de Ferran         NaN         13.0           NaN
# 20         Marcelo Renato       468.0          6.0         SA 34
# 21      Danglares Martins       467.0          3.0         SA 86
# 22            Diego Lemos       466.0          2.0         SA 30
# 23               Senna PH       466.0          2.0         SA 73
# 24        Milena Barcelos       466.0          3.0         SA 73
# 25   Alessandro Silvestre       466.0          7.0         SA 81
# 26            Dimas Silva       466.0          4.0         SA 86
# 27      Guilherme Augusto       465.0          1.0         SA 33
# 28          Rafael Mendes       465.0          8.0         SA 81
# 29         Mike Gasparzin       464.0          5.0         SA 55
# 30         Luciano Araujo       462.0          4.0         SA 55
# 31              Guina Roo       462.0         20.0         alone
# 32         Daniel Mueller       461.0          9.0         SA 81
# 33               Edu Abud       460.0         10.0         SA 85
# 34   Rostislav Lutchichin       460.0         10.0         alone
# 35      Welington Cacador       458.0          5.0         SA 86
# 36        Ramon Scontrino       456.0         10.0         alone
# 37             Jose Melos       456.0         26.0         SA 43
# 38        Dionizio Junior       455.0          7.0         SA 73
# 39      Andre Luiz Ferraz       450.0         12.0         SA 82
# 40          Felix Morales       445.0         62.0         alone
# 41      Jose Carlos Brito       435.0          7.0         SA 86
# 42             Luis Alves       427.0          NaN         SA 85
# 43              José X Ju       422.0          NaN         SA 55
# 44       Marcelo M. Marau       412.0          9.0         SA 86
# 45         Douglas Guerra       408.0         34.0         SA 77
# 46         Paulo Tsalikis       408.0         14.0         SA 33
# 47          Robert Anicio       402.0         22.0         SA 73
# 48          Samuel Araujo       324.0         60.0         SA 81
# 49      Thiago C. Laverde       111.0         98.0         SA 34
# 50       Cicero Verissimo         0.0        100.0         SA 82
# 51           Dimy Adriano         NaN          NaN           NaN
# 52        Fernando Mendes         NaN          NaN           NaN
# 53           Jose Antonio         NaN         10.0           NaN
# 54        Valter Ramos Jr         NaN         51.0         SA 81
# 55         Victor Pereira         NaN          NaN           NaN
# 56                    NaN         NaN          NaN           NaN
# 57                    NaN         NaN          NaN           NaN
# 58                    NaN         NaN          NaN           NaN
#
#                                                                         SUNDAY group names  \
# 0            Adriano Martins, Alan Parrini, Douglas Guerra, Gil de Ferran, Marcellus Lopes
# 1                                                  Joseilton Araujo, Copersucar Fittipaldi
# 2                                                                Dom Alonso, Jose Fernando
# 3                                                                      Ninguém  //  nobody
# 4        Alessandro Silvestre, Daniel Mueller, Edson Marcelo, Rafael Mendes, Samuel Araujo
# 5                                                                      Ninguém  //  nobody
# 6                                                                      Ninguém  //  nobody
# 7    Edu Abud, Eliesley Reis, Felipe Cimadon, Guilherme Gontier, Sidney Junior, Luis Alves
# 8                                                  Joseilton Araujo, Copersucar Fittipaldi
# 9                Dionizio Junior, Milena Barcelos, Renato Ribeiro, Robert Anicio, Senna PH
# 10           Adriano Martins, Alan Parrini, Douglas Guerra, Gil de Ferran, Marcellus Lopes
# 11      Andre Luiz Ferraz, Cicero Verissimo, Jeremias Preuss, Lucas Kern, Fernando Mendes
# 12                                                               Dom Alonso, Jose Fernando
# 13                                 José X Ju, Julio Campos, Luciano Araujo, Mike Gasparzin
# 14      Andre Luiz Ferraz, Cicero Verissimo, Jeremias Preuss, Lucas Kern, Fernando Mendes
# 15   Edu Abud, Eliesley Reis, Felipe Cimadon, Guilherme Gontier, Luis Alves, Sidney Junior
# 16   Edu Abud, Eliesley Reis, Felipe Cimadon, Guilherme Gontier, Luis Alves, Sidney Junior
# 17           Adriano Martins, Alan Parrini, Douglas Guerra, Gil de Ferran, Marcellus Lopes
# 18   Edu Abud, Eliesley Reis, Felipe Cimadon, Guilherme Gontier, Luis Alves, Sidney Junior
# 19                                                                                     NaN
# 20                                                      Marcelo Renato, Thiago C. Laverde
# 21  Danglares Martins, Dimas Silva, Jose Carlos Brito, Marcelo M. Marau, Welington Cacador
# 22                                                          Diego Lemos, Thiago C. Laverde
# 23               Dionizio Junior, Milena Barcelos, Renato Ribeiro, Robert Anicio, Senna PH
# 24               Dionizio Junior, Milena Barcelos, Renato Ribeiro, Robert Anicio, Senna PH
# 25       Alessandro Silvestre, Daniel Mueller, Edson Marcelo, Rafael Mendes, Samuel Araujo
# 26  Danglares Martins, Dimas Silva, Jose Carlos Brito, Marcelo M. Marau, Welington Cacador
# 27                                                       Guilherme Augusto, Paulo Tsalikis
# 28       Alessandro Silvestre, Daniel Mueller, Edson Marcelo, Rafael Mendes, Samuel Araujo
# 29                                 José X Ju, Julio Campos, Luciano Araujo, Mike Gasparzin
# 30                                 José X Ju, Julio Campos, Luciano Araujo, Mike Gasparzin
# 31                                                                     Ninguém  //  nobody
# 32       Alessandro Silvestre, Daniel Mueller, Edson Marcelo, Rafael Mendes, Samuel Araujo
# 33   Edu Abud, Eliesley Reis, Felipe Cimadon, Guilherme Gontier, Luis Alves, Sidney Junior
# 34                                                                     Ninguém  //  nobody
# 35  Danglares Martins, Dimas Silva, Jose Carlos Brito, Marcelo M. Marau, Welington Cacador
# 36                                                                     Ninguém  //  nobody
# 37                                             Jose Melos, Marcelo Renato, Valter Ramos Jr
# 38               Dionizio Junior, Milena Barcelos, Renato Ribeiro, Robert Anicio, Senna PH
# 39      Andre Luiz Ferraz, Cicero Verissimo, Jeremias Preuss, Lucas Kern, Fernando Mendes
# 40                                                                     Ninguém  //  nobody
# 41  Danglares Martins, Dimas Silva, Jose Carlos Brito, Marcelo M. Marau, Welington Cacador
# 42   Edu Abud, Eliesley Reis, Felipe Cimadon, Guilherme Gontier, Luis Alves, Sidney Junior
# 43                                 José X Ju, Julio Campos, Luciano Araujo, Mike Gasparzin
# 44  Danglares Martins, Dimas Silva, Jose Carlos Brito, Marcelo M. Marau, Welington Cacador
# 45           Adriano Martins, Alan Parrini, Douglas Guerra, Gil de Ferran, Marcellus Lopes
# 46                                                       Guilherme Augusto, Paulo Tsalikis
# 47               Dionizio Junior, Milena Barcelos, Renato Ribeiro, Robert Anicio, Senna PH
# 48       Alessandro Silvestre, Daniel Mueller, Edson Marcelo, Rafael Mendes, Samuel Araujo
# 49                                                      Marcelo Renato, Thiago C. Laverde
# 50      Andre Luiz Ferraz, Cicero Verissimo, Jeremias Preuss, Lucas Kern, Fernando Mendes
# 51                                                                                     NaN
# 52                                                                                     NaN
# 53                                                                                     NaN
# 54       Alessandro Silvestre, Daniel Mueller, Edson Marcelo, Rafael Mendes, Samuel Araujo
# 55                                                                                     NaN
# 56                                                                                     NaN
# 57                                                                                     NaN
# 58                                                                                     NaN
#
#    Score for P10 on his group  # of 470 on his group  Unnamed: 12  Min Avg  \
# 0                         466                    1.0          NaN     38.0
# 1                         467                    7.0          NaN      NaN
# 2                         429                    0.0          NaN     36.0
# 3                           X                    1.0          NaN      NaN
# 4                           X                    1.0          NaN     30.0
# 5                           X                    0.0          NaN      NaN
# 6                         464                    5.0          NaN      NaN
# 7                         460                    3.0          NaN     35.0
# 8                         467                    9.0          NaN     44.0
# 9                         445                    0.0          NaN      NaN
# 10                        448                    0.0          NaN      NaN
# 11                        452                    0.0          NaN     28.0
# 12                          X                    1.0          NaN     34.0
# 13                        454                    0.0          NaN      NaN
# 14                        452                    0.0          NaN      NaN
# 15                        468                    3.0          NaN     35.0
# 16                        460                    3.0          NaN     37.0
# 17                        360                    1.0          NaN     36.0
# 18                        460                    3.0          NaN      NaN
# 19                        450                    1.0          NaN     36.0
# 20                        465                    1.0          NaN     32.0
# 21                        374                    2.0          NaN     25.0
# 22                          X                    0.0          NaN     40.0
# 23                          X                    0.0          NaN     32.0
# 24                        443                    0.0          NaN     30.0
# 25                        460                    1.0          NaN     35.0
# 26                        374                    2.0          NaN     20.0
# 27                        419                    0.0          NaN     34.0
# 28                        465                    1.0          NaN     35.0
# 29                        458                    0.0          NaN     34.0
# 30                        450                    1.0          NaN      NaN
# 31                          X                    0.0          NaN      NaN
# 32                        441                    5.0          NaN     30.0
# 33                        460                    3.0          NaN     38.0
# 34                          X                    1.0          NaN      NaN
# 35                        374                    2.0          NaN     20.0
# 36                          X                    0.0          NaN      NaN
# 37                        460                    1.0          NaN     34.0
# 38                        455                    0.0          NaN     30.0
# 39                        452                    0.0          NaN     30.0
# 40                        469                    6.0          NaN      NaN
# 41                        374                    2.0          NaN     20.0
# 42                        NaN                    NaN          NaN     35.0
# 43                        NaN                    NaN          NaN     38.0
# 44                        374                    2.0          NaN     25.0
# 45                          X                    3.0          NaN     38.0
# 46                        441                    0.0          NaN     36.0
# 47                        443                    0.0          NaN     32.0
# 48                        463                    1.0          NaN     30.0
# 49                          X                    0.0          NaN     40.0
# 50                        452                    0.0          NaN     25.0
# 51                        NaN                    NaN          NaN      NaN
# 52                        NaN                    NaN          NaN      NaN
# 53                        390                    0.0          NaN     20.0
# 54                        463                    1.0          NaN      NaN
# 55                        NaN                    NaN          NaN      NaN
# 56                        NaN                    NaN          NaN      NaN
# 57                        NaN                    NaN          NaN      NaN
# 58                        NaN                    NaN          NaN      NaN
#
#    Max Avg  Sabado MIN  Sabado MAX  Unnamed: 17 AVG qualy + opening  \
# 0       40       385.0       415.0          NaN                37,8
# 1      NaN      -235.0      -235.0          NaN                47,0
# 2       38       397.0       427.0          NaN                36,0
# 3      NaN         0.0         0.0          NaN                 NaN
# 4       35       292.0       392.0          NaN                35,1
# 5      NaN         0.0         0.0          NaN                 NaN
# 6      NaN         0.0         0.0          NaN                36,9
# 7     38,1       392.0       470.0          NaN                34,0
# 8      NaN       453.0      -200.0          NaN                43,5
# 9      NaN      -168.0      -168.0          NaN                33,7
# 10     NaN      -170.0      -170.0          NaN                37,7
# 11      30       317.0       347.0          NaN                32,1
# 12      36       331.0       361.0          NaN                35,9
# 13     NaN      -168.0      -168.0          NaN                38,4
# 14     NaN      -138.0      -138.0          NaN                29,8
# 15    36,4       441.0       476.0          NaN                34,0
# 16     NaN       498.0      -428.0          NaN                34,2
# 17      38       376.0       406.0          NaN                32,8
# 18     NaN      -473.0      -473.0          NaN                34,0
# 19      38       379.0       409.0          NaN                37,7
# 20      34       328.0       358.0          NaN                51,2
# 21      30       251.0       351.0          NaN                26,9
# 22      42       407.0       437.0          NaN                40,9
# 23      34       316.0       346.0          NaN                33,5
# 24      32       303.0       333.0          NaN                32,2
# 25      40       384.0       470.0          NaN                34,2
# 26      25       239.0       339.0          NaN                24,6
# 27      36       353.0       383.0          NaN                34,7
# 28      40       375.0       470.0          NaN                38,5
# 29      36       366.0       396.0          NaN                39,6
# 30     NaN      -215.0      -215.0          NaN                35,8
# 31     NaN         0.0         0.0          NaN                 NaN
# 32      35       291.0       391.0          NaN                34,1
# 33    38,5       469.0       478.0          NaN                38,1
# 34     NaN      -208.0      -208.0          NaN                42,1
# 35      25       243.0       343.0          NaN                25,2
# 36     NaN      -457.0      -457.0          NaN                30,4
# 37      36       325.0       355.0          NaN                38,7
# 38      32       305.0       335.0          NaN                32,1
# 39      32       303.0       333.0          NaN                31,3
# 40     NaN      -278.0      -278.0          NaN                38,1
# 41      25       238.0       338.0          NaN                24,5
# 42     NaN       360.0      -515.0          NaN                37,1
# 43      40       407.0       437.0          NaN                39,4
# 44      30       247.0       347.0          NaN                26,4
# 45      40       391.0       421.0          NaN                37,9
# 46      38       380.0       410.0          NaN                34,6
# 47      34       323.0       353.0          NaN                33,9
# 48      35       317.0       417.0          NaN                30,3
# 49      42       432.0       462.0          NaN                40,1
# 50      30       294.0       394.0          NaN                29,2
# 51      30         0.0       300.0          NaN                 NaN
# 52      30         0.0       300.0          NaN                 NaN
# 53      20       244.0       244.0          NaN                11,2
# 54     NaN      -173.0      -173.0          NaN                43,3
# 55      30         0.0       300.0          NaN                 NaN
# 56     NaN         0.0         0.0          NaN                 NaN
# 57     NaN         0.0         0.0          NaN                 NaN
# 58     NaN         NaN         NaN          NaN                 NaN
#
#     SUM qualy + opening  Races qualy + opening  Unnamed: 21  Unnamed: 22  \
# 0                 567.0                   15.0          NaN           -3
# 1                 705.0                   15.0          NaN          705
# 2                 540.0                   15.0          NaN            0
# 3                   0.0                    0.0          NaN            0
# 4                 702.0                   20.0          NaN          102
# 5                   0.0                    0.0          NaN            0
# 6                 369.0                   10.0          NaN          369
# 7                 850.0                   25.0          NaN          -25
# 8                 652.0                   15.0          NaN           -1
# 9                 506.0                   15.0          NaN          506
# 10                565.0                   15.0          NaN          565
# 11                481.0                   15.0          NaN           61
# 12                538.0                   15.0          NaN           28
# 13                576.0                   15.0          NaN          576
# 14                447.0                   15.0          NaN          447
# 15                850.0                   25.0          NaN          -25
# 16                855.0                   25.0          NaN          -71
# 17                164.0                    5.0          NaN         -376
# 18                850.0                   25.0          NaN          850
# 19                565.0                   15.0          NaN           25
# 20                461.0                    9.0          NaN          -19
# 21                537.0                   20.0          NaN           37
# 22                613.0                   15.0          NaN           13
# 23                503.0                   15.0          NaN           23
# 24                483.0                   15.0          NaN           33
# 25                684.0                   20.0          NaN          -16
# 26                491.0                   20.0          NaN           91
# 27                521.0                   15.0          NaN           11
# 28                770.0                   20.0          NaN           70
# 29                594.0                   15.0          NaN           84
# 30                215.0                    6.0          NaN          215
# 31                  0.0                    0.0          NaN            0
# 32                681.0                   20.0          NaN           81
# 33                952.0                   25.0          NaN           -2
# 34                632.0                   15.0          NaN          632
# 35                503.0                   20.0          NaN          103
# 36                759.0                   25.0          NaN          759
# 37                542.0                   14.0          NaN           32
# 38                482.0                   15.0          NaN           32
# 39                469.0                   15.0          NaN           19
# 40                610.0                   16.0          NaN          610
# 41                490.0                   20.0          NaN           90
# 42                854.0                   23.0          NaN          -21
# 43                591.0                   15.0          NaN           21
# 44                527.0                   20.0          NaN           27
# 45                568.0                   15.0          NaN           -2
# 46                519.0                   15.0          NaN          -21
# 47                508.0                   15.0          NaN           28
# 48                606.0                   20.0          NaN            6
# 49                601.0                   15.0          NaN            1
# 50                438.0                   15.0          NaN          -62
# 51                  0.0                    0.0          NaN            0
# 52                  0.0                    0.0          NaN            0
# 53                 56.0                    5.0          NaN         -244
# 54                173.0                    4.0          NaN          173
# 55                  0.0                    0.0          NaN            0
# 56                  0.0                    0.0          NaN            0
# 57                  0.0                    0.0          NaN            0
# 58                  NaN                    NaN          NaN            0
#
#     Unnamed: 23  SAT score  SAT races SAT result SAT group  Unnamed: 28  \
# 0            33      382.0       10.0        Yes     SA 27          NaN
# 1          -705      470.0       10.0        Yes     alone          NaN
# 2            30      397.0       10.0        Yes     SA 82          NaN
# 3             0        NaN        NaN        NaN       NaN          NaN
# 4            -2      394.0       10.0        Yes     SA 51          NaN
# 5             0        NaN        NaN        NaN       NaN          NaN
# 6          -369      369.0       10.0        Yes     SA 31          NaN
# 7           103      367.0       10.0        Yes     SA 85          NaN
# 8          -652      452.0       10.0        Yes     alone          NaN
# 9          -506      338.0       10.0        Yes     SA 47          NaN
# 10         -565      395.0       10.0        Yes     SA 88          NaN
# 11          -31      378.0       10.0        Yes     SA 32          NaN
# 12            2      359.0       10.0        Yes     SA 26          NaN
# 13         -576      408.0       10.0        Yes     SA 47          NaN
# 14         -447      309.0       10.0        Yes     alone          NaN
# 15           60      416.0       10.0        Yes     SA 85          NaN
# 16         -855      427.0       10.0        Yes     SA 85          NaN
# 17          406        NaN        NaN        NaN       NaN          NaN
# 18         -850      377.0       10.0        Yes     SA 85          NaN
# 19            5      404.0       10.0        Yes     SA 88          NaN
# 20           49      309.0        4.0        Yes     alone          NaN
# 21           63      288.0       10.0        Yes     SA 35          NaN
# 22           17      420.0       10.0        Yes     alone          NaN
# 23            7      339.0       10.0        Yes     SA 88          NaN
# 24           -3      336.0       10.0        Yes     SA 82          NaN
# 25          102      368.0       10.0        Yes     SA 51          NaN
# 26            9      330.0       10.0        Yes     SA 49          NaN
# 27           19      364.0       10.0        Yes     SA 48          NaN
# 28           25      445.0       10.0        Yes     alone          NaN
# 29          -54      450.0       10.0        Yes     SA 82          NaN
# 30         -215        NaN        NaN        NaN       NaN          NaN
# 31            0        NaN        NaN        NaN       NaN          NaN
# 32           19      372.0       10.0        Yes     SA 51          NaN
# 33           11      467.0       10.0        Yes     SA 85          NaN
# 34         -632      424.0       10.0        Yes     alone          NaN
# 35           -3      346.0       10.0        Yes     SA 49          NaN
# 36         -759      302.0       10.0        Yes     alone          NaN
# 37           -2      357.0        9.0        Yes     SA 27          NaN
# 38           -2      337.0       10.0        Yes     SA 82          NaN
# 39           11      322.0       10.0        Yes     SA 82          NaN
# 40         -610      332.0        8.0        Yes     alone          NaN
# 41           10      328.0       10.0        Yes     SA 49          NaN
# 42         -854      339.0        8.0        Yes     SA 85          NaN
# 43            9      428.0       10.0         No     SA 88          NaN
# 44           73      274.0       10.0        Yes     SA 35          NaN
# 45           32      389.0       10.0        Yes     SA 88          NaN
# 46           51      359.0       10.0        Yes     SA 48          NaN
# 47            2      351.0       10.0        Yes     SA 48          NaN
# 48           94      323.0       10.0        Yes     alone          NaN
# 49           29      433.0       10.0        Yes     SA 47          NaN
# 50          162      232.0        5.0        Yes     alone          NaN
# 51          300        NaN        NaN        NaN       NaN          NaN
# 52          300        NaN        NaN        NaN       NaN          NaN
# 53          244        NaN        NaN        NaN       NaN          NaN
# 54         -173        NaN        NaN        NaN       NaN          NaN
# 55          300        NaN        NaN        NaN       NaN          NaN
# 56            0        NaN        NaN        NaN       NaN          NaN
# 57            0        NaN        NaN        NaN       NaN          NaN
# 58            0        NaN        NaN        NaN       NaN          NaN
#
#    AVG 3 qualy  Score 3 qualy  Races 3 qualy Actual qualy day  \
# 0         37,0          185.0            5.0              THU
# 1         47,0          235.0            5.0              FRI
# 2         28,6          143.0            5.0              WED
# 3          NaN            0.0            0.0              NaN
# 4         30,8          308.0           10.0              THU
# 5          NaN            0.0            0.0              NaN
# 6          NaN            0.0            0.0              NaN
# 7         32,2          483.0           15.0              FRI
# 8         40,0          200.0            5.0              THU
# 9         33,6          168.0            5.0              WED
# 10        34,0          170.0            5.0              WED
# 11        20,6          103.0            5.0              THU
# 12        35,8          179.0            5.0              WED
# 13        33,6          168.0            5.0              WED
# 14        27,6          138.0            5.0              THU
# 15        28,9          434.0           15.0              FRI
# 16        28,5          428.0           15.0              FRI
# 17        32,8          164.0            5.0              WED
# 18        31,5          473.0           15.0              FRI
# 19        32,2          161.0            5.0              WED
# 20        30,4          152.0            5.0              WED
# 21        24,9          249.0           10.0              THU
# 22        38,6          193.0            5.0              THU
# 23        32,8          164.0            5.0              WED
# 24        29,4          147.0            5.0              WED
# 25        31,6          316.0           10.0              THU
# 26        16,1          161.0           10.0              THU
# 27        31,4          157.0            5.0              WED
# 28        32,5          325.0           10.0              THU
# 29        28,8          144.0            5.0              WED
# 30        35,8          215.0            6.0              THU
# 31         NaN            0.0            0.0              NaN
# 32        30,9          309.0           10.0              THU
# 33        32,3          485.0           15.0              FRI
# 34        41,6          208.0            5.0              WED
# 35        15,7          157.0           10.0              THU
# 36        30,5          457.0           15.0              FRI
# 37        37,0          185.0            5.0              WED
# 38        29,0          145.0            5.0              THU
# 39        29,4          147.0            5.0              WED
# 40        34,8          278.0            8.0              THU
# 41        16,2          162.0           10.0              THU
# 42        34,3          515.0           15.0              FRI
# 43        32,6          163.0            5.0              WED
# 44        25,3          253.0           10.0              THU
# 45        35,8          179.0            5.0              WED
# 46        32,0          160.0            5.0              WED
# 47        31,4          157.0            5.0              WED
# 48        28,3          283.0           10.0              THU
# 49        33,6          168.0            5.0              WED
# 50        20,6          206.0           10.0              THU
# 51         NaN            0.0            0.0              NaN
# 52         NaN            0.0            0.0              NaN
# 53          11           56.0            5.0              NaN
# 54        43,3          173.0            4.0              THU
# 55         NaN            0.0            0.0              NaN
# 56         NaN            0.0            0.0              NaN
# 57         NaN            0.0            0.0              NaN
# 58         NaN            NaN            NaN              NaN
#
#            Planned qualy day  Unnamed: 34  FRI score  FRI races FRI result  \
# 0    THURSDAY (Quinta-feira)          NaN        NaN        NaN        NaN
# 1            ACE (Gabaritar)          NaN      141.0        3.0        Yes
# 2   WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 3                        NaN          NaN        NaN        NaN        NaN
# 4    THURSDAY (Quinta-feira)          NaN        NaN        NaN        NaN
# 5                        NaN          NaN        NaN        NaN        NaN
# 6                        NaN          NaN        NaN        NaN        NaN
# 7       FRIDAY (Sexta-feira)          NaN      235.0        5.0        Yes
# 8            ACE (Gabaritar)          NaN        NaN        NaN        NaN
# 9   WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 10  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 11   THURSDAY (Quinta-feira)          NaN        NaN        NaN        NaN
# 12  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 13           ACE (Gabaritar)          NaN        NaN        NaN        NaN
# 14   THURSDAY (Quinta-feira)          NaN        NaN        NaN        NaN
# 15      FRIDAY (Sexta-feira)          NaN      234.0        5.0        Yes
# 16      FRIDAY (Sexta-feira)          NaN      231.0        5.0        Yes
# 17  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 18      FRIDAY (Sexta-feira)          NaN      225.0        5.0        Yes
# 19  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 20  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 21   THURSDAY (Quinta-feira)          NaN        NaN        NaN        NaN
# 22   THURSDAY (Quinta-feira)          NaN        NaN        NaN        NaN
# 23  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 24  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 25   THURSDAY (Quinta-feira)          NaN        NaN        NaN        NaN
# 26   THURSDAY (Quinta-feira)          NaN        NaN        NaN        NaN
# 27  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 28   THURSDAY (Quinta-feira)          NaN        NaN        NaN        NaN
# 29  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 30  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 31                       NaN          NaN        NaN        NaN        NaN
# 32   THURSDAY (Quinta-feira)          NaN        NaN        NaN        NaN
# 33      FRIDAY (Sexta-feira)          NaN      235.0        5.0        Yes
# 34                       NaN          NaN        NaN        NaN        NaN
# 35   THURSDAY (Quinta-feira)          NaN        NaN        NaN        NaN
# 36      FRIDAY (Sexta-feira)          NaN      159.0        5.0        Yes
# 37  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 38   THURSDAY (Quinta-feira)          NaN        NaN        NaN        NaN
# 39  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 40                       NaN          NaN        NaN        NaN        NaN
# 41   THURSDAY (Quinta-feira)          NaN        NaN        NaN        NaN
# 42      FRIDAY (Sexta-feira)          NaN      231.0        5.0        Yes
# 43  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 44   THURSDAY (Quinta-feira)          NaN        NaN        NaN        NaN
# 45  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 46  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 47  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 48   THURSDAY (Quinta-feira)          NaN        NaN        NaN        NaN
# 49  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 50   THURSDAY (Quinta-feira)          NaN        NaN        NaN        NaN
# 51                       NaN          NaN        NaN        NaN        NaN
# 52                       NaN          NaN        NaN        NaN        NaN
# 53      FRIDAY (Sexta-feira)          NaN        NaN        NaN        NaN
# 54  WEDNESDAY (Quarta-feira)          NaN        NaN        NaN        NaN
# 55                       NaN          NaN        NaN        NaN        NaN
# 56                       NaN          NaN        NaN        NaN        NaN
# 57                       NaN          NaN        NaN        NaN        NaN
# 58                       NaN          NaN        NaN        NaN        NaN
#
#     THU score  THU races THU result  WED score  WED races WED result
# 0       185.0        5.0        Yes        0.0        0.0         No
# 1        94.0        2.0         No        0.0        0.0         No
# 2         NaN        NaN        NaN      143.0        5.0        Yes
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4       194.0        5.0        Yes      114.0        5.0         No
# 5         NaN        NaN        NaN        NaN        NaN        NaN
# 6         NaN        NaN        NaN        NaN        NaN        NaN
# 7       124.0        5.0         No      124.0        5.0         No
# 8       200.0        5.0        Yes        NaN        NaN        NaN
# 9         NaN        NaN        NaN      168.0        5.0        Yes
# 10        NaN        NaN        NaN      170.0        5.0        Yes
# 11      103.0        5.0        Yes        0.0        0.0         No
# 12        NaN        NaN        NaN      179.0        5.0        Yes
# 13        NaN        NaN        NaN      168.0        5.0        Yes
# 14      138.0        5.0        Yes        0.0        0.0         No
# 15      100.0        5.0         No      100.0        5.0         No
# 16      100.0        5.0         No       97.0        5.0         No
# 17        NaN        NaN        NaN      164.0        5.0        Yes
# 18      124.0        5.0         No      124.0        5.0         No
# 19        NaN        NaN        NaN      161.0        5.0        Yes
# 20        NaN        NaN        NaN      152.0        5.0        Yes
# 21      150.0        5.0        Yes       99.0        5.0         No
# 22      193.0        5.0        Yes        0.0        0.0         No
# 23        NaN        NaN        NaN      164.0        5.0        Yes
# 24        NaN        NaN        NaN      147.0        5.0        Yes
# 25      191.0        5.0        Yes      125.0        5.0         No
# 26      146.0        5.0        Yes       15.0        5.0         No
# 27        NaN        NaN        NaN      157.0        5.0        Yes
# 28      181.0        5.0        Yes      144.0        5.0         No
# 29        NaN        NaN        NaN      144.0        5.0        Yes
# 30      168.0        5.0        Yes       47.0        1.0         No
# 31        NaN        NaN        NaN        NaN        NaN        NaN
# 32      168.0        5.0        Yes      141.0        5.0         No
# 33      103.0        5.0         No      147.0        5.0         No
# 34        NaN        NaN        NaN      208.0        5.0        Yes
# 35      142.0        5.0        Yes       15.0        5.0         No
# 36      143.0        5.0         No      155.0        5.0         No
# 37        NaN        NaN        NaN      185.0        5.0        Yes
# 38      145.0        5.0        Yes        0.0        0.0         No
# 39        NaN        NaN        NaN      147.0        5.0        Yes
# 40      173.0        5.0        Yes      105.0        3.0         No
# 41      147.0        5.0        Yes       15.0        5.0         No
# 42      142.0        5.0         No      142.0        5.0         No
# 43        NaN        NaN        NaN      163.0        5.0        Yes
# 44      155.0        5.0        Yes       98.0        5.0         No
# 45        NaN        NaN        NaN      179.0        5.0        Yes
# 46        NaN        NaN        NaN      160.0        5.0        Yes
# 47        NaN        NaN        NaN      157.0        5.0        Yes
# 48      159.0        5.0        Yes      124.0        5.0         No
# 49        NaN        NaN        NaN      168.0        5.0        Yes
# 50      147.0        5.0        Yes       59.0        5.0         No
# 51        NaN        NaN        NaN        NaN        NaN        NaN
# 52        NaN        NaN        NaN        NaN        NaN        NaN
# 53        NaN        NaN        NaN       56.0        5.0         No
# 54      173.0        4.0        Yes        NaN        NaN        NaN
# 55        NaN        NaN        NaN        NaN        NaN        NaN
# 56        NaN        NaN        NaN        NaN        NaN        NaN
# 57        NaN        NaN        NaN        NaN        NaN        NaN
# 58        NaN        NaN        NaN        NaN        NaN        NaN

# %% [markdown]
# #### Data clean up

# %%
# Subsetting the data to get the columns I want for initial analysis
cleaned_data = raw_data[['Player',
                         'Score for P1 on his group', '# of 470 on his group',
                         'SAT score', 'SAT races',
                         'FRI score', 'FRI races',
                         'THU score', 'THU races',
                         'WED score', 'WED races']]

# cleaned_data

# %%
target_variable = cleaned_data['Score for P1 on his group'].dropna()

ideal_target_variable = np.random.normal(460,3,50)

fig, ax = plt.subplots(1,2, figsize=(15,8))
sns.histplot(target_variable, ax=ax[0], bins='fd')
ax[0].set_ylabel('# of clan players', size=18)
ax[0].set_xlabel("Score of P1 in player's group", size=18)
ax[0].set_title("Distribution of P1 scores from last GP", size=18)
ax[0].tick_params(axis='x', labelsize=18)
ax[0].tick_params(axis='y', labelsize=18)

sns.histplot(ideal_target_variable, ax=ax[1], bins='fd')
ax[1].set_xlabel("Score of P10 in player's group", size=18)
ax[1].set(ylabel=None)
ax[1].set_title("Ideal distribution of scores", size=18)
ax[1].tick_params(axis='x', labelsize=18)
ax[1].tick_params(axis='y', labelsize=18)

plt.tight_layout()
plt.show()
# plt.savefig("figure.png")

# %% [markdown]
# #### No data on the easiness of the Final Round group? Can't do much with that... Deleting those rows (for all I know, that can also mean the player didn't make it to the Final Round). And again, not pointing the finger at anybody.

# %%
cleaned_data = cleaned_data.dropna(how='all',
                                  subset=['Score for P1 on his group',
                                          '# of 470 on his group'])
# cleaned_data

# %% [markdown]
# So, whenever there are missing data, one has to be really careful when dealing with that. Sometimes data is missing randomly, and when that's the case, there are well established methods to deal with them. However, the general approach will depend on the goals and having a deep understanding of how the data is generated. In my case, I want to know whether performance on Qualifying+Opening Round impacts easiness of groups. That means I need points and races for Opening Round.
# However, I know that people can qualify on Wednesday, Thursday, or Friday, so that if somebody qualifies on Wednesday, no data will be present for Thursday and Friday. That's OK, and what I can do is fill up those entries with zeroes.
# The problem would be if somebody qualified on Thursday, but no information is given for what happened on Wednesday. It's anybody's guess. Did that person just not race on Wednesday (in which case I can perfectly assign zero)? Or did that person race 3 times, but we don't have that info (in which case, assigning zero would cause serious problems).
# #### What I see above is that we are also missing scores and races for the Opening Round. I can't do much with that either.

# %%
cleaned_data = cleaned_data.dropna(how='all',
                                  subset=['SAT score',
                                          'SAT races'])
# cleaned_data

# %% [markdown]
# There are two players who have the situation I mentioned above. Looking at the other columns to see if they do have information.
# For one player, the issue was with his account, so he could not race on Thursday and Wednesday. I can safely assume I can place zeroes there.\*
# For another player, he entered the clan on Saturday, and could not remember his qualy score. This data point is unreliable, so it should be eliminated.
#
# \*But this brings another dimension: Does it matter if you entered the event on Friday and raced only on Friday (same for Thursday), or does it matter if you enter the event on Wednesday, and simply don't race until Friday?

# %%
cleaned_data = cleaned_data.loc[cleaned_data['Player'] != "Jose Melos"].drop(axis='columns',
                                                                             columns='Player')
cleaned_data

# %% [markdown]
# Now filling up with zeroes

# %%
cleaned_data = cleaned_data.fillna(0)
cleaned_data

# %% [markdown]
# #### Nice and clean data ready for exploration!

# %%
sns.pairplot(cleaned_data)
plt.show()

# %% [markdown]
# The above plot is mainly to rule out colinearities. If one exists, I would see the dot plots showing some sort of trend where as one variable goes up, the other goes up or down. But no trend is observed.
# What worries me is that linear regression usually assumes a normal distribution. But the output variables (score for P1, and # of 470) do not follow a normal distribution (bell curve). I would imagine the P10 or P5 score better following a normal distribution.
# It's just funny that the only thing that looks like a normal distribution are the Saturday scores. People were targeting a score apparently.
# Will go ahead with linear regression, but I'm already suspecting that I might need to include the averages. I also think this is difficult since I can't see a relationship between the output variables and any of the possible independent variables (no trends).

# %%
import statsmodels.api as sm

# %% [markdown]
# #### Using # of 470 on his group first

# %%
features = cleaned_data[['SAT score', 'SAT races',
                         'FRI score', 'FRI races',
                         'THU score', 'THU races',
                         'WED score', 'WED races']]
response = cleaned_data['# of 470 on his group']
features = sm.add_constant(features)
model = sm.OLS(response,features)
smOLS = model.fit()

# %%
smOLS.summary()

# %% [markdown]
# #### Now using score of P1

# %%
features = cleaned_data[['SAT score', 'SAT races',
                         'FRI score', 'FRI races',
                         'THU score', 'THU races',
                         'WED score', 'WED races']]
response = cleaned_data['Score for P1 on his group']
features = sm.add_constant(features)
model = sm.OLS(response,features)
smOLS = model.fit()

# %%
smOLS.summary()

# %% [markdown]
# ### Nothing to look at here
# Essentially, I wanted to see if any variable would show high coeff, and low P>t. Only SAT races does, but it does that simply because the model was so clever to realize that 47 times 10 roughly equals the score obtained by those who got P1. So smart (sarcasm)!
# Will now look at averages instead!

# %%
cleaned_data_2 = raw_data[['Player',
                           'Score for P1 on his group', '# of 470 on his group',
                           'Races qualy + opening',
                           'AVG qualy + opening',
                           'SAT score', 'SAT races', 'AVG 3 qualy',
                           'Actual qualy day']]

# taking away those without entries for sunday
cleaned_data_2 = cleaned_data_2.dropna(how='all',
                                       subset=['Score for P1 on his group',
                                               '# of 470 on his group'])

# taking away those without entries for saturday
cleaned_data_2 = cleaned_data_2.dropna(how='all',
                                       subset=['SAT score',
                                               'SAT races'])

# Now taking away the unreliable entry and player names
cleaned_data_2 = cleaned_data_2.loc[cleaned_data_2['Player'] != "Jose Melos"].drop(axis='columns',
                                                                                   columns='Player')

cleaned_data_2

# %% [markdown]
# Getting Saturday average and keeping just the averages

# %%
cleaned_data_2['SAT_avg'] = cleaned_data_2['SAT score']/cleaned_data_2['SAT races']
cleaned_data_2 = cleaned_data_2[['Score for P1 on his group', '# of 470 on his group',
                                 'Races qualy + opening',
                                 'AVG qualy + opening',
                                 'AVG 3 qualy', 'SAT_avg',
                                 'Actual qualy day']]

# %%
sns.pairplot(cleaned_data_2)
plt.show()
# plt.savefig('../visual.png')

# %% [markdown]
# #### This looks better! But there seems to be a strong co-linearity between average for qualy, and average for Saturday. In a way, this simply reflects strategies: Players sandbagging on both stages (to various degrees), or players going all in at every stage.

# %%
fig5,ax5 = plt.subplots(2,2, figsize=(10,10))
sns.stripplot(x="Races qualy + opening", y="# of 470 on his group",
              data=cleaned_data_2, ax=ax5[0,0], linewidth=1)
sns.boxplot(x="Races qualy + opening", y="# of 470 on his group",
            data=cleaned_data_2, ax=ax5[0,0], whis=np.inf)
ax5[0,0].set_ylabel('# of 470 on his group', size=18)
ax5[0,0].set_xlabel("Races qualy + opening", size=18)
ax5[0,0].tick_params(axis='x', labelsize=18)
ax5[0,0].tick_params(axis='y', labelsize=18)

sns.stripplot(x="Actual qualy day", y="# of 470 on his group",
              data=cleaned_data_2, ax=ax5[0,1], linewidth=1)
sns.boxplot(x="Actual qualy day", y="# of 470 on his group",
            data=cleaned_data_2, ax=ax5[0,1], whis=np.inf)
ax5[0,1].set_ylabel('# of 470 on his group', size=18)
ax5[0,1].set_xlabel("Day of quali", size=18)
ax5[0,1].tick_params(axis='x', labelsize=18)
ax5[0,1].tick_params(axis='y', labelsize=18)

sns.stripplot(x="Races qualy + opening", y="Score for P1 on his group",
              data=cleaned_data_2, ax=ax5[1,0], linewidth=1)
sns.boxplot(x="Races qualy + opening", y="Score for P1 on his group",
            data=cleaned_data_2, ax=ax5[1,0], whis=np.inf)
ax5[1,0].set_ylabel('Score for P1 on his group', size=18)
ax5[1,0].set_xlabel("Races qualy + opening", size=18)
ax5[1,0].tick_params(axis='x', labelsize=18)
ax5[1,0].tick_params(axis='y', labelsize=18)

sns.stripplot(x="Actual qualy day", y="Score for P1 on his group",
              data=cleaned_data_2, ax=ax5[1,1], linewidth=1)
sns.boxplot(x="Actual qualy day", y="Score for P1 on his group",
              data=cleaned_data_2, ax=ax5[1,1], whis=np.inf)
ax5[1,1].set_ylabel('Score for P1 on his group', size=18)
ax5[1,1].set_xlabel("Day of quali", size=18)
ax5[1,1].tick_params(axis='x', labelsize=18)
ax5[1,1].tick_params(axis='y', labelsize=18)

plt.tight_layout()
# plt.savefig("difficulty_group_races.png")
plt.show()

# %% [markdown]
# #### Linear regression
# This is looking better, so I'll further rescale the variables so the results can be better interpreted

# %%
# Don't want to deal with the numpy -> pandas conversion
# AKA, no sklearn
features = cleaned_data_2[['AVG qualy + opening', 'Races qualy + opening',
                           'AVG 3 qualy','SAT_avg']]

cleaned_data_2[['AVG qualy + opening',
                'Races qualy + opening',
                'AVG 3 qualy',
                'SAT_avg']] = (features - features.min())/(features.max() -features.min())

# %%
print(f"Number of players with complete average data: {len(cleaned_data_2)}")

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
features = cleaned_data_2[['AVG qualy + opening', 'Races qualy + opening', 'SAT_avg', 'AVG 3 qualy', 'Actual qualy day']]
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(sparse=False), [4])], remainder='passthrough')
trans_features = ct.fit_transform(features)
features_trans = pd.DataFrame(trans_features, index=features.index, columns=['FRI','THU','WED',
                                                                             'AVG qualy + opening',
                                                                             'Races qualy + opening',
                                                                             'SAT_avg','AVG 3 qualy'])

# %% [markdown]
# ## \# of 470

# %%
response = cleaned_data_2['# of 470 on his group']
model = sm.OLS(response, features_trans)
smOLS = model.fit()
smOLS.summary()

# %%
model = sm.OLS(response, features_trans.drop(columns=['Races qualy + opening']))
smOLS = model.fit()
smOLS.summary()

# %%
model = sm.OLS(response, features_trans.drop(columns=['Races qualy + opening','AVG qualy + opening']))
smOLS = model.fit()
smOLS.summary()

# %%
model = sm.OLS(response, features_trans.drop(columns=['Races qualy + opening','AVG qualy + opening', 'AVG 3 qualy']))
smOLS = model.fit()
smOLS.summary()

# %% [markdown]
# ## Yeap, cannot conclude much from Linear Regression. When evaluating each average individually (not shown), I couldn't also see statistically significant coefficients.
#
#   ### Idea: Let's use score of whoever ends on P10 as the measure of easiness of the Sunday group. I expect this score to follow a bell curve better than the score of P1 (which is very skewed towards 470). Essentially, that will be the score above which players could get good medals in the event, and not just the generic finalist medal. It will also be on the same terms as the other variables, since they are also scores. I could simply divide those scores by 10, and then normalize, to have very pretty dataset for linear regression.

# %% [markdown]
# However, there are other ideas floating around. It turns out that players ending up together on Saturday's Opening round tend to also end up together in the Final round. It would be difficult to assess that with this data, since players may sandbag or go all-in on Saturday, so their scores aren't a reflection of their true skill level.
# But I could test, later on, if this notion is true, if I quantify clustering on saturday, and see if it is any different on sunday. The problem there is that I would need data on all players, not just Elite F1.

# %% [markdown]
# #### Let's simply look at groups, whether they share general traits

# %%
groupings_data = raw_data[['Player', 'SUN DAY group', 'SAT group', 'AVG qualy + opening',
                           'SAT score', 'SAT races', 'AVG 3 qualy', 'Races qualy + opening', 'Actual qualy day']]

groupings_data['SAT_avg'] = groupings_data['SAT score']/groupings_data['SAT races']
groupings_data = groupings_data[['SUN DAY group','SAT group',
                                 'AVG qualy + opening', 'SAT_avg',
                                 'AVG 3 qualy', 'Races qualy + opening', 'Actual qualy day']]

# taking away those without entries for Sunday groups
groupings_data = groupings_data.dropna(how='all',
                                       subset=['SUN DAY group'])

# taking away those without entries for averages
groupings_data = groupings_data.dropna(how='any',
                                       subset=['AVG qualy + opening',
                                               'SAT_avg',
                                               'AVG 3 qualy'])

groupings_data.sort_values(by='SUN DAY group')

# %% [markdown]
# #### Sunday grouping logic

# %%
# Taking away groups where only one person was present
# f = groupings_data['SUN DAY group'].value_counts()
# groupings_data = groupings_data[groupings_data['SUN DAY group'].isin(f[f>1].index)]

# %%
fig1, ax1 = plt.subplots(1,3, figsize=(18,7))
sns.boxplot(x="AVG qualy + opening", y="SUN DAY group",
              data=groupings_data, ax=ax1[0], whis=np.inf)
sns.stripplot(x="AVG qualy + opening", y="SUN DAY group",
              data=groupings_data, ax=ax1[0], linewidth=1)
ax1[0].set_title("Is it overall average?")

sns.boxplot(x="SAT_avg", y="SUN DAY group",
              data=groupings_data, ax=ax1[1], whis=np.inf)
sns.stripplot(x="SAT_avg", y="SUN DAY group",
              data=groupings_data, ax=ax1[1], linewidth=1)
ax1[1].set(ylabel=None)
ax1[1].set_title("Is it Saturday average?")

sns.boxplot(x="AVG 3 qualy", y="SUN DAY group",
              data=groupings_data, ax=ax1[2], whis=np.inf)
sns.stripplot(x="AVG 3 qualy", y="SUN DAY group",
              data=groupings_data, ax=ax1[2], linewidth=1)
ax1[2].set(ylabel=None)
ax1[2].set_title("Is it just Quali average?")

plt.tight_layout()
plt.show()
# plt.savefig("grouping_by_average.png")

# %% [markdown]
# #### Saturday logic

# %%
fig2, ax2 = plt.subplots(1,1)
sns.boxplot(x="AVG 3 qualy", y="SAT group",
              data=groupings_data.dropna(), ax=ax2, whis=np.inf)
sns.stripplot(x="AVG 3 qualy", y="SAT group",
              data=groupings_data.dropna(), ax=ax2, linewidth=1)

plt.show()

# %%
fig3, ax3 = plt.subplots(1,1)
sns.boxplot(x="Races qualy + opening", y="SUN DAY group",
              data=groupings_data, ax=ax3, whis=np.inf)
sns.stripplot(x="Races qualy + opening", y="SUN DAY group",
              data=groupings_data, ax=ax3, linewidth=1)

# plt.savefig("number_of_races.png")
plt.show()

# %% [markdown]
# ### Co-occurrence of Saturday group vs. Sunday group

# %%
groupings = groupings_data[['SUN DAY group','SAT group', 'Races qualy + opening',
                            'Actual qualy day']].dropna()
f = groupings['SAT group'] != '-'
groupings.loc[f].sort_values(by='SAT group')

# %% [markdown]
# ## there seems to be a hierarchy or a sequential criteria applied to determine groups. Among those with 15 races, what was their average?

# %%
g = groupings_data['Races qualy + opening'] == 15
h = groupings_data['Races qualy + opening'] == 20
k = groupings_data['Races qualy + opening'] == 25

fig4, ax4 = plt.subplots(1,3,figsize=(18,7))
sns.boxplot(x="AVG qualy + opening", y="SUN DAY group",
              data=groupings_data.loc[g], ax=ax4[0], whis=np.inf)
sns.stripplot(x="AVG qualy + opening", y="SUN DAY group",
              data=groupings_data.loc[g], ax=ax4[0], linewidth=1)
ax4[0].set_title("15 races")

sns.boxplot(x="AVG qualy + opening", y="SUN DAY group",
              data=groupings_data.loc[h], ax=ax4[1], whis=np.inf)
sns.stripplot(x="AVG qualy + opening", y="SUN DAY group",
              data=groupings_data.loc[h], ax=ax4[1], linewidth=1)
ax4[1].set_title("20 races")

sns.boxplot(x="AVG qualy + opening", y="SUN DAY group",
              data=groupings_data.loc[k], ax=ax4[2], whis=np.inf)
sns.stripplot(x="AVG qualy + opening", y="SUN DAY group",
              data=groupings_data.loc[k], ax=ax4[2], linewidth=1)
ax4[2].set_title("25 races")

plt.tight_layout()
# plt.savefig("average_spread_per_races.png")
plt.show()

# %% [markdown]
# hum, does it happens because we have more groups in one they them the other?
# We had 10 groups for weds, 2 groups for thurs and 1 for friday
# 10 groups for people who qualified with 5 races;
# 2 groups for people who qualified with 10 races;
# 1 groups for people whi qualified with 15

# %%
sun_friday = raw_data[['SUN DAY group', 'SAT group',
                       'Races 3 qualy',
                       'Actual qualy day']].dropna(subset=['SUN DAY group', 'Actual qualy day', 'Races 3 qualy'])
sun_friday.groupby('Races 3 qualy')['SUN DAY group'].unique()

# %%
sun_friday.groupby('Races 3 qualy')['SUN DAY group'].nunique()
